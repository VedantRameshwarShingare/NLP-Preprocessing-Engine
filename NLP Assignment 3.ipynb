# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in c:\users\asus\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: torch in c:\users\asus\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.9.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\asus\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: setuptools<82 in c:\users\asus\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\asus\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.27.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\asus\anaconda3\lib\site-packages (from typer->transformers) (8.1.7)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.2.0)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.2)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.7)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.14.0)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
model_name = "microsoft/DialoGPT-medium"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--microsoft--DialoGPT-medium. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/863M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/293 [00:00<?, ?it/s]
# '[WinError 10054] An existing connection was forcibly closed by the remote host' thrown while requesting HEAD https://huggingface.co/microsoft/DialoGPT-medium/resolve/main/generation_config.json
# Retrying in 1s [Retry 1/5].
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_transports\default.py", line 69, in map_httpcore_exceptions
#     yield
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_transports\default.py", line 233, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py", line 268, in handle_request
#     raise exc
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py", line 251, in handle_request
#     response = connection.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\connection.py", line 103, in handle_request
#     return self._connection.handle_request(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\http11.py", line 133, in handle_request
#     raise exc
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\http11.py", line 111, in handle_request
#     ) = self._receive_response_headers(**kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\http11.py", line 176, in _receive_response_headers
#     event = self._receive_event(timeout=timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpcore\_sync\http11.py", line 226, in _receive_event
#     raise RemoteProtocolError(msg)
# httpcore.RemoteProtocolError: Server disconnected without sending a response.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\ASUS\anaconda3\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\transformers\safetensors_conversion.py", line 117, in auto_conversion
#     raise e
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\transformers\safetensors_conversion.py", line 113, in auto_conversion
#     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\transformers\utils\hub.py", line 278, in cached_file
#     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\transformers\utils\hub.py", line 512, in cached_files
#     raise e
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\transformers\utils\hub.py", line 422, in cached_files
#     hf_hub_download(
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py", line 89, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\file_download.py", line 986, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\file_download.py", line 1061, in _hf_hub_download_to_cache_dir
#     (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#                                                                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\file_download.py", line 1653, in _get_metadata_or_catch_error
#     metadata = get_hf_file_metadata(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py", line 89, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\file_download.py", line 1576, in get_hf_file_metadata
#     response = _httpx_follow_relative_redirects_with_backoff(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py", line 685, in _httpx_follow_relative_redirects_with_backoff
#     response = http_backoff(
#                ^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py", line 559, in http_backoff
#     return next(
#            ^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\huggingface_hub\utils\_http.py", line 467, in _http_backoff_base
#     response = client.request(method=method, url=url, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_client.py", line 827, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_client.py", line 1015, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_transports\default.py", line 232, in handle_request
#     with map_httpcore_exceptions():
#   File "C:\Users\ASUS\anaconda3\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\httpx\_transports\default.py", line 86, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.RemoteProtocolError: Server disconnected without sending a response.

# %%
# Chat history
chat_history_ids = None

print("🤖 Chatbot: Hello! I am your AI assistant. Type 'exit' to stop.\n")

while True:
    
    user_input = input("You: ")
    
    # Exit condition
    if user_input.lower() in ["exit", "quit"]:
        print("🤖 Chatbot: Goodbye! Have a great day!")
        break
    
    # Encode input
    new_input_ids = tokenizer.encode(user_input + tokenizer.eos_token, return_tensors='pt')
    
    # Maintain conversation history
    if chat_history_ids is not None:
        bot_input_ids = torch.cat([chat_history_ids, new_input_ids], dim=-1)
    else:
        bot_input_ids = new_input_ids
    
    # Generate response
    chat_history_ids = model.generate(
        bot_input_ids,
        max_length=1000,
        pad_token_id=tokenizer.eos_token_id,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7
    )
    
    # Decode response
    bot_response = tokenizer.decode(
        chat_history_ids[:, bot_input_ids.shape[-1]:][0],
        skip_special_tokens=True
    )
    
    print("🤖 Chatbot:", bot_response)
# Out:
# 🤖 Chatbot: Hello! I am your AI assistant. Type 'exit' to stop.
# You:  hi
# 🤖 Chatbot: Hello! :D
# You:  what is ai?
# 🤖 Chatbot: AI is an online program
# You:  what is transformer model?
# 🤖 Chatbot: I think it's an app
# You:  exit
# 🤖 Chatbot: Goodbye! Have a great day!
